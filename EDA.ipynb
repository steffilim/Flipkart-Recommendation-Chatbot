# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = 'newData/flipkart_cleaned.csv'
flipkart = pd.read_csv(filepath)
flipkart
# Out:
#                                 uniq_id  \
# 0      c2d766ca982eca8304150849735ffef9
# 1      7f7036a6d550aaa89d34c77bd39a5e48
# 2      f449ec65dcbc041b6ae5e6a32717d01b
# 3      0973b37acd0c664e3de26e97e5571454
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7
# ...                                 ...
# 19901  7179d2f6c4ad50a17d014ca1d2815156
# 19902  71ac419198359d37b8fe5e3fffdfee09
# 19903  93e9d343837400ce0d7980874ece471c
# 19904  669e79b8fa5d9ae020841c0c97d5e935
# 19905  cb4fa87a874f715fff567f7b7b3be79c
#
#                                   product_name  \
# 0          alisha solid women's cycling shorts
# 1          fabhomedecor fabric double sofa bed
# 2                                   aw bellies
# 3          alisha solid women's cycling shorts
# 4        sicons all purpose arnica dog shampoo
# ...                                        ...
# 19901           walldesign small vinyl sticker
# 19902  wallmantra large vinyl stickers sticker
# 19903  elite collection medium acrylic sticker
# 19904  elite collection medium acrylic sticker
# 19905  elite collection medium acrylic sticker
#
#                                    product_category_tree               pid  \
# 0      ['clothing', "women's clothing", 'lingerie, sl...  srteh2ff9kedefgf
# 1      ['furniture', 'living room furniture', 'sofa b...  sbeeh3qgu7mfyjfy
# 2      ['footwear', "women's footwear", 'ballerinas',...  shoeh4grsubjgzxe
# 3      ['clothing', "women's clothing", 'lingerie, sl...  srteh2f6huzmq6sj
# 4      ['pet supplies', 'grooming', 'skin & coat care...  psoeh3zydmsyarj5
# ...                                                  ...               ...
# 19901  ['baby care', 'baby & kids gifts', 'stickers',...  stie7kfjakstdy9g
# 19902  ['baby care', 'baby & kids gifts', 'stickers',...  stie9f5urnqgjcgh
# 19903  ['baby care', 'baby & kids gifts', 'stickers',...  stie7vaydkqzebsd
# 19904  ['baby care', 'baby & kids gifts', 'stickers',...  stie8ysveppcz42y
# 19905  ['baby care', 'baby & kids gifts', 'stickers',...  stie88kn9zdsgzky
#
#        retail_price  discounted_price  discount  \
# 0             999.0             379.0     62.06
# 1           32157.0           22646.0     29.58
# 2             999.0             499.0     50.05
# 3             699.0             267.0     61.80
# 4             220.0             210.0      4.55
# ...             ...               ...       ...
# 19901        1500.0             730.0     51.33
# 19902        1429.0            1143.0     20.01
# 19903        1299.0             999.0     23.09
# 19904        1499.0            1199.0     20.01
# 19905        1499.0             999.0     33.36
#
#                                              description       overall_rating  \
# 0      key features of alisha solid women's cycling s...  no rating available
# 1      fabhomedecor fabric double sofa bed (finish co...  no rating available
# 2      key features of aw bellies sandals wedges heel...  no rating available
# 3      key features of alisha solid women's cycling s...  no rating available
# 4      specifications of sicons all purpose arnica do...  no rating available
# ...                                                  ...                  ...
# 19901  buy walldesign small vinyl sticker for rs.730 ...  no rating available
# 19902  buy wallmantra large vinyl stickers sticker fo...  no rating available
# 19903  buy elite collection medium acrylic sticker fo...  no rating available
# 19904  buy elite collection medium acrylic sticker fo...  no rating available
# 19905  buy elite collection medium acrylic sticker fo...  no rating available
#
#                   brand                             product_specifications  \
# 0                alisha  number of contents in sales package: pack of 3...
# 1          fabhomedecor  installation & demo details: installation and ...
# 2                    aw  ideal for: women occasion: casual color: red o...
# 3                alisha  number of contents in sales package: pack of 2...
# 4                sicons  pet type: dog brand: sicons quantity: 500 ml m...
# ...                 ...                                                ...
# 19901        walldesign  number of contents in sales package: pack of 5...
# 19902        wallmantra  number of contents in sales package: pack of 1...
# 19903  elite collection  number of contents in sales package: pack of 1...
# 19904  elite collection  number of contents in sales package: pack of 1...
# 19905  elite collection  number of contents in sales package: pack of 3...
#
#        percentage_discount
# 0                62.062062
# 1                29.576764
# 2                50.050050
# 3                61.802575
# 4                 4.545455
# ...                    ...
# 19901            51.333333
# 19902            20.013996
# 19903            23.094688
# 19904            20.013342
# 19905            33.355570
#
# [19906 rows x 12 columns]

# %%
orderdata = pd.read_csv("newData/synthetic_v2.csv")
orderdata = orderdata.rename(columns={'Product ID': 'uniq_id'})
orderdata.dtypes
# Out:
# Order ID                        object
# uniq_id                         object
# Product Quantity                 int64
# Product Price Each             float64
# Order Total                    float64
# Order Date                      object
# Purchase Address                object
# User rating for the product    float64
# User ID                         object
# User Age                         int64
# User Occupation                 object
# User Income                      int64
# User Interests                  object
# User Ethnicity                  object
# dtype: object

# %% [markdown]
# ### User demographics

# %%
palette = sns.color_palette("RdBu", 10)

fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(x='User Income', data=orderdata, palette=palette)
ax.set_title('Distribution of user income')

plt.show()
# Out:
# /var/folders/rd/t3xtrw6x6cn_9qvx9ywrkj4c0000gn/T/ipykernel_6191/581039657.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='User Income', data=orderdata, palette=palette)

# %%
palette = sns.color_palette("RdBu", 10)

fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(x='User Ethnicity', data=orderdata, palette=palette)
ax.set_title('Graph of user ethnicity')

plt.show()
# Out:
# /var/folders/rd/t3xtrw6x6cn_9qvx9ywrkj4c0000gn/T/ipykernel_6191/3032691099.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='User Ethnicity', data=orderdata, palette=palette)

# %%
palette = sns.color_palette("RdBu", 10)

fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(x='User rating for the product', data=orderdata, palette=palette, bins=10)
ax.set_title('Graph of user ratings')

plt.show()
# Out:
# /var/folders/rd/t3xtrw6x6cn_9qvx9ywrkj4c0000gn/T/ipykernel_6191/758320158.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='User rating for the product', data=orderdata, palette=palette, bins=10)

# %%
age_bins = pd.cut(orderdata['User Age'], bins=range(15, 75, 5))
age_bins = age_bins.astype('category')
age_bins = age_bins.cat.set_categories(age_bins.cat.categories, ordered=True)
plt.figure(figsize=(10, 6))
sns.countplot(age_bins)
plt.title('Distribution of User Age in 5-Year Intervals')
plt.xlabel('User Age Group')
plt.ylabel('Count')
plt.show()
